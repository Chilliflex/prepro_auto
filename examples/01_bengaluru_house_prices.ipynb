# %%
# %pip install prepro-auto
# Out:
# ...
#   Using cached prepro_auto-1.0.0b4-py3-none-any.whl (159 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 1. Load your data however you like

# %% [markdown]
# ##### Type 1: For CSV, Excel, JSON, or Parquet file Only

# %%
import pandas as pd
import prepro_auto
df = pd.read_csv(r"C:\Users\pande\Downloads\BHP\model\Bengaluru_House_Data.csv")
session = prepro_auto.launch(df)
# Out:
# PrePro Auto workbench ready (no upload — your DataFrame is already loaded):
#   http://127.0.0.1:8721/workbench?job=679a2069-3a39-4fc6-9988-dabc58908739

# %%
session.update(df)
# Out:
# 16:31:32 | INFO    | app.services.versioning_service | Committed v1 for 0458771a (notebook_edit) shape=(13320,9)
# <PrePro Auto session job=0458771a url=http://127.0.0.1:8721/workbench?job=0458771a-2aad-4590-843d-84b603026b41>

# %% [markdown]
# ##### Type 2: For CSV, Excel, JSON, or Parquet file Only

# %%
import prepro_auto

session = prepro_auto.launch_file(r"C:\Users\pande\Downloads\BHP\model\Bengaluru_House_Data.csv")
# Out:
# 16:24:36 | INFO    | app.services.file_reader | CSV read with encoding=utf-8-sig, shape=(13320, 9)
# Read Bengaluru_House_Data.csv: shape=(13320, 9), dtypes={'area_type': 'str', 'availability': 'str', 'location': 'str', 'size': 'str', 'society': 'str'}, ...
# PrePro Auto workbench ready (no upload — your DataFrame is already loaded):
#   http://127.0.0.1:8721/workbench?job=0458771a-2aad-4590-843d-84b603026b41
